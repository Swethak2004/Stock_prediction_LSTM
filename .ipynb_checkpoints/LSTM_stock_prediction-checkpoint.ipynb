# %%
import pandas_datareader as pdr
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import numpy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM,Flatten
import tensorflow as tf

# %%
key = '2ee7028bcd4761febc087aad43d6b60031734a6f'

start_date = datetime(2018, 1, 1)
end_date = datetime(2023, 8, 6)

df1 = pdr.get_data_tiingo('AMZN', api_key=key, start=start_date, end=end_date)
df2 = pdr.get_data_tiingo('TSLA', api_key=key, start=start_date, end=end_date)
df3 = pdr.get_data_tiingo('TWTR', api_key=key, start=start_date, end=end_date)
df4 = pdr.get_data_tiingo('AAPL', api_key=key, start=start_date, end=end_date)
df5 = pdr.get_data_tiingo('GOOG', api_key=key, start=start_date, end=end_date)
# Out:
# <ipython-input-2-231d242a31b3>:6: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df1 = pdr.get_data_tiingo('AMZN', api_key=key, start=start_date, end=end_date)
# <ipython-input-2-231d242a31b3>:7: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df2 = pdr.get_data_tiingo('TSLA', api_key=key, start=start_date, end=end_date)
# <ipython-input-2-231d242a31b3>:8: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df3 = pdr.get_data_tiingo('TWTR', api_key=key, start=start_date, end=end_date)
# <ipython-input-2-231d242a31b3>:9: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df4 = pdr.get_data_tiingo('AAPL', api_key=key, start=start_date, end=end_date)
# ...

# %%
df1.to_csv("Amazon_stocks.csv")
df2.to_csv("Tesla_stocks.csv")
df3.to_csv("Twitter_stocks.csv")
df4.to_csv("Apple_stock.csv")
df5.to_csv("Google_stocks.csv")

# %%
df1=pd.read_csv("/content/Amazon_stocks.csv")

# %%
df1.head()
# Out:
#   symbol                       date    close     high      low     open  \
# 0   AMZN  2018-01-02 00:00:00+00:00  1189.01  1190.00  1170.51  1172.00
# 1   AMZN  2018-01-03 00:00:00+00:00  1204.20  1205.49  1188.30  1188.30
# 2   AMZN  2018-01-04 00:00:00+00:00  1209.59  1215.87  1204.66  1205.00
# 3   AMZN  2018-01-05 00:00:00+00:00  1229.14  1229.14  1210.00  1217.51
# 4   AMZN  2018-01-08 00:00:00+00:00  1246.87  1253.08  1232.03  1236.00
#
#     volume  adjClose  adjHigh   adjLow  adjOpen  adjVolume  divCash  \
# 0  2587899   59.4505  59.5000  58.5255  58.6000   51757980      0.0
# 1  3044664   60.2100  60.2745  59.4150  59.4150   60893280      0.0
# 2  3000366   60.4795  60.7935  60.2330  60.2500   60007320      0.0
# 3  3430148   61.4570  61.4570  60.5000  60.8755   68602960      0.0
# 4  4177533   62.3435  62.6540  61.6015  61.8000   83550660      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
df1.tail()
# Out:
#      symbol                       date   close    high       low     open  \
# 1402   AMZN  2023-07-31 00:00:00+00:00  133.68  133.87  132.3800  133.200
# 1403   AMZN  2023-08-01 00:00:00+00:00  131.69  133.69  131.6199  133.550
# 1404   AMZN  2023-08-02 00:00:00+00:00  128.21  130.23  126.8200  130.154
# 1405   AMZN  2023-08-03 00:00:00+00:00  128.91  129.84  126.4100  127.480
# 1406   AMZN  2023-08-04 00:00:00+00:00  139.57  143.63  139.3200  141.060
#
#          volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 1402   41901516    133.68   133.87  132.3800  133.200   41901516      0.0
# 1403   42298925    131.69   133.69  131.6199  133.550   42298925      0.0
# 1404   51027614    128.21   130.23  126.8200  130.154   51027614      0.0
# 1405   91163736    128.91   129.84  126.4100  127.480   91163736      0.0
# 1406  153128470    139.57   143.63  139.3200  141.060  153128470      0.0
#
#       splitFactor
# 1402          1.0
# 1403          1.0
# ...

# %%
df1=df1['open']

# %%
df1.shape
# Out:
# (1407,)

# %%
df1.head()
# Out:
# 0    1172.00
# 1    1188.30
# 2    1205.00
# 3    1217.51
# 4    1236.00
# Name: open, dtype: float64

# %%
plt.plot(df1)

# %%
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
training_size=int(len(df)*0.65)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
training_size,test_size
# Out:
# (914, 493)

# %%
def Preprocess_data(dataset,time_step):
  X,Y=[],[]
  for i in range(len(dataset)-time_step-1):
    a=dataset[i:(i+time_step),0]
    X.append(a)
    b=dataset[i+time_step,0]
    Y.append(b)

  return numpy.array(X),numpy.array(Y)

# %%
x_train,y_train = Preprocess_data(train_data,200)
x_test,y_test = Preprocess_data(test_data,200)

# %%
x_train
# Out:
# array([[0.29749809, 0.30195018, 0.30651153, ..., 0.47121162, 0.46766088,
#         0.46451983],
#        [0.30195018, 0.30651153, 0.30992844, ..., 0.46766088, 0.46451983,
#         0.48071397],
#        [0.30651153, 0.30992844, 0.3149787 , ..., 0.46451983, 0.48071397,
#         0.47489621],
#        ...,
#        [0.85822681, 0.86488037, 0.85176172, ..., 0.89102207, 0.88731752,
#         0.87599694],
#        [0.86488037, 0.85176172, 0.8398749 , ..., 0.88731752, 0.87599694,
#         0.88027696],
#        [0.85176172, 0.8398749 , 0.81365126, ..., 0.87599694, 0.88027696,
#         0.874085  ]])

# %%
x_train=x_train.reshape(x_train.shape[0],x_train.shape[1],1)
x_test=x_test.reshape(x_test.shape[0],x_test.shape[1],1)
x_test.shape
# Out:
# (292, 200, 1)

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(200,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 200, 50)           10400
#
#  lstm_1 (LSTM)               (None, 200, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 21s 131ms/step - loss: 0.1563 - accuracy: 0.0014 - val_loss: 0.0444 - val_accuracy: 0.0034
# Epoch 2/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0164 - accuracy: 0.0014 - val_loss: 0.0584 - val_accuracy: 0.0034
# Epoch 3/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0083 - accuracy: 0.0014 - val_loss: 0.0372 - val_accuracy: 0.0034
# Epoch 4/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0052 - accuracy: 0.0014 - val_loss: 0.0343 - val_accuracy: 0.0034
# Epoch 5/100
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0029 - accuracy: 0.0014 - val_loss: 0.0260 - val_accuracy: 0.0034
# Epoch 6/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0020 - accuracy: 0.0014 - val_loss: 0.0178 - val_accuracy: 0.0034
# Epoch 7/100
# ...

# %%
train_pred=model.predict(x_train)
test_pred=model.predict(x_test)
# Out:
# ...
# 10/10 [==============================] - 0s 9ms/step

# %%
train_pred
# Out:
# array([[0.47683507],
#        [0.47189206],
#        [0.46860424],
#        [0.46630976],
#        [0.4646914 ],
#        [0.46302783],
#        [0.4615854 ],
#        [0.4595421 ],
#        [0.45621997],
#        [0.45196426],
#        [0.4451114 ],
#        [0.43711734],
#        [0.42960826],
#        [0.42399108],
#        [0.42032287],
#        [0.41793278],
#        [0.41709304],
#        [0.4185431 ],
#        [0.4216878 ],
#        [0.42544305],
#        [0.42854643],
#        [0.43064624],
#        [0.43077683],
#        [0.42912447],
#        [0.42603874],
#        [0.42040214],
#        [0.41395962],
#        [0.40734133],
#        [0.40137023],
#        [0.39686048],
#        [0.39440155],
#        [0.39457998],
#        [0.39708576],
#        [0.40231824],
#        [0.40944138],
#        [0.41577572],
#        [0.42144328],
#        [0.42527252],
#        [0.42778876],
#        [0.42916748],
#        [0.42979404],
#        [0.42940658],
#        [0.427294  ],
# ...

# %%
y_train
# Out:
# array([0.48071397, 0.47489621, 0.46497323, 0.4646564 , 0.4532503 ,
#        0.46184311, 0.44262537, 0.42794439, 0.43078772, 0.38330602,
#        0.40620288, 0.4208265 , 0.43586529, 0.430124  , 0.41941167,
#        0.43433847, 0.4567355 , 0.45058997, 0.44123238, 0.42786245,
#        0.42978258, 0.40921283, 0.41098547, 0.40812029, 0.3700153 ,
#        0.39882825, 0.39172949, 0.39773845, 0.40784169, 0.41820168,
#        0.43488201, 0.43611384, 0.46068502, 0.45700863, 0.41846116,
#        0.44309789, 0.42091118, 0.43570414, 0.43324593, 0.43625041,
#        0.42477876, 0.40511308, 0.39801158, 0.39884464, 0.38271605,
#        0.37752376, 0.34502349, 0.35127554, 0.37457664, 0.37980717,
#        0.39003605, 0.37758112, 0.39255162, 0.39528024, 0.41503059,
#        0.43206872, 0.42887032, 0.4256009 , 0.42547525, 0.41849667,
#        0.42313995, 0.43740304, 0.43625041, 0.44499071, 0.43652354,
#        0.42969518, 0.42561728, 0.43365563, 0.42630558, 0.42294057,
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_pred
# Out:
# array([[ 6.14731252e-01],
#        [ 5.92751324e-01],
#        [ 5.39893091e-01],
#        [ 4.68713582e-01],
#        [ 3.91774148e-01],
#        [ 3.17919165e-01],
#        [ 2.51993120e-01],
#        [ 1.95930943e-01],
#        [ 1.49857342e-01],
#        [ 1.12963580e-01],
#        [ 8.40373635e-02],
#        [ 6.18099347e-02],
#        [ 4.50456142e-02],
#        [ 3.26379687e-02],
#        [ 2.36236397e-02],
#        [ 1.72007196e-02],
#        [ 1.26685826e-02],
#        [ 9.42732021e-03],
#        [ 7.02996273e-03],
#        [ 5.14313485e-03],
#        [ 3.54651455e-03],
#        [ 2.12829653e-03],
#        [ 8.15956853e-04],
#        [-4.34044749e-04],
#        [-1.65036321e-03],
#        [-2.85618752e-03],
#        [-4.08406276e-03],
#        [-5.31548448e-03],
#        [-6.51280396e-03],
#        [-7.63417035e-03],
#        [-8.65316205e-03],
#        [-9.54339467e-03],
#        [-1.02744661e-02],
#        [-1.08371582e-02],
#        [-1.12602953e-02],
# ...

# %%
train_predict=scaler.inverse_transform(train_pred)
test_predict=scaler.inverse_transform(test_pred)

# %%
train_predict
# Out:
# array([[1828.5885],
#        [1810.4912],
#        [1798.4537],
#        [1790.0532],
#        [1784.128 ],
#        [1778.0375],
#        [1772.7565],
#        [1765.2755],
#        [1753.1125],
#        [1737.5315],
#        [1712.4418],
#        [1683.174 ],
#        [1655.6816],
#        [1635.1161],
#        [1621.686 ],
#        [1612.9354],
#        [1609.861 ],
#        [1615.1699],
#        [1626.6833],
#        [1640.432 ],
#        [1651.7942],
#        [1659.4819],
#        [1659.9601],
#        [1653.9105],
#        [1642.613 ],
#        [1621.9763],
#        [1598.3889],
#        [1574.1581],
#        [1552.2966],
#        [1535.7855],
#        [1526.783 ],
#        [1527.4362],
#        [1536.6104],
#        [1555.7675],
#        [1581.8467],
#        [1605.038 ],
#        [1625.7881],
#        [1639.8077],
#        [1649.0201],
#        [1654.0679],
#        [1656.3619],
#        [1654.9434],
#        [1647.2087],
#        [1632.933 ],
#        [1614.182 ],
# ...

# %%
test_predict
# Out:
# array([[2.33345410e+03],
#        [2.25298120e+03],
#        [2.05945654e+03],
#        [1.79885413e+03],
#        [1.51716345e+03],
#        [1.24676562e+03],
#        [1.00539716e+03],
#        [8.00142395e+02],
#        [6.31457703e+02],
#        [4.96382233e+02],
#        [3.90477600e+02],
#        [3.09098541e+02],
#        [2.47721008e+02],
#        [2.02294128e+02],
#        [1.69290863e+02],
#        [1.45775284e+02],
#        [1.29182205e+02],
#        [1.17315308e+02],
#        [1.08538101e+02],
#        [1.01630043e+02],
#        [9.57845001e+01],
#        [9.05921173e+01],
#        [8.57873840e+01],
#        [8.12108765e+01],
#        [7.67576904e+01],
#        [7.23429260e+01],
#        [6.78474274e+01],
#        [6.33389473e+01],
#        [5.89553185e+01],
#        [5.48497772e+01],
#        [5.11190453e+01],
#        [4.78597260e+01],
#        [4.51831245e+01],
#        [4.31229973e+01],
#        [4.15738068e+01],
#        [4.02789803e+01],
#        [3.91273727e+01],
# ...

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 2482.256689847167

# %%
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 291.9315183131484

# %%
import numpy as np
import matplotlib.pyplot as plt

look_back = 200

trainPredictPlot = np.full_like(df1, np.nan)
testPredictPlot = np.full_like(df1, np.nan)

trainPredictPlot[look_back:look_back+len(train_predict)] = train_predict.reshape(-1)

testPredictPlot[look_back*2+len(train_predict)+1:len(df1)-1] = test_predict.reshape(-1)

plt.plot(df1)
plt.plot(trainPredictPlot,color='red')
plt.plot(testPredictPlot,color='blue')
plt.show()

# %%
df1.shape
# Out:
# (1407,)

# %%
print(test_data[997:])
# Out:
# []

# %%
x_input=test_data[997:].reshape(1,-1)
x_input.shape
# Out:
# (1, 0)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()
temp_input
# Out:
# [[-0.0104947779327631],
#  [-0.010933935642242432],
#  [-0.01201736181974411],
#  [-0.01370110735297203],
#  [-0.015855051577091217],
#  [-0.01833447255194187],
#  [-0.02101362682878971],
#  [-0.023797014728188515],
#  [-0.026618922129273415],
#  [-0.029438132420182228],
#  [-0.03223129361867905],
#  [-0.03498702496290207],
#  [-0.03770127892494202],
#  [-0.04037401080131531],
#  [-0.043007075786590576],
#  [-0.04560299217700958],
#  [-0.04816421866416931],
#  [-0.05069292336702347],
#  [-0.05319081246852875],
#  [-0.055659227073192596],
#  [-0.058099135756492615],
#  [-0.060511283576488495],
#  [-0.06289619952440262],
#  [-0.06525426357984543],
#  [-0.06758573651313782],
#  [-0.06989084929227829],
#  [-0.07216973602771759],
#  [-0.07442249357700348],
#  [-0.07664920389652252],
#  [-0.0788499191403389],
#  [-0.08102469891309738],
#  [-0.08317354321479797],
#  [-0.08529648184776306],
#  [-0.08739353716373444],
#  [-0.08946472406387329],
#  [-0.09151006489992142],
# ...

# %%
n_days = 200
x_input = test_data[-200:].reshape(1, -1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()
lst_output = []
n_steps = 200

for i in range(n_days):
    if len(temp_input) > 100:
        x_input = np.array(temp_input[0:])
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())

extended_predictions = scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

day_new_extended = np.arange(len(df1), len(df1) + n_days)

# %%
plt.plot(df1)
plt.savefig('predicted_plot.jpg')
plt.plot(day_new_extended,extended_predictions, label="Test Prediction", color="green")
plt.savefig('plot.jpg')

# %%
model.save('Amazon_Lstm_stock_model.h5')
