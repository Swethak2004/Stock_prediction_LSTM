# %% [markdown]
# # **TESLA LSTM STOCK PRICE PREDICTION**

# %% [markdown]
# **Importing Required Packages:**

# %%
import pandas_datareader as pdr
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import numpy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM,Flatten
import tensorflow as tf

# %% [markdown]
# **Data Collection Tesla Data**

# %%
df1=pd.read_csv("Tesla_stocks.csv")

# %%
df1.head()
# Out:
#   symbol                       date   close    high     low    open   volume  \
# 0   TSLA  2018-01-02 00:00:00+00:00  320.53  322.11  311.00  312.00  4326988
# 1   TSLA  2018-01-03 00:00:00+00:00  317.25  325.25  315.55  321.00  4185665
# 2   TSLA  2018-01-04 00:00:00+00:00  314.62  318.55  305.68  312.87  9915932
# 3   TSLA  2018-01-05 00:00:00+00:00  316.58  317.24  312.00  316.62  4578729
# 4   TSLA  2018-01-08 00:00:00+00:00  336.41  337.02  315.50  316.00  9777059
#
#     adjClose    adjHigh     adjLow    adjOpen  adjVolume  divCash  splitFactor
# 0  21.368667  21.474000  20.733333  20.800000   64904820      0.0          1.0
# 1  21.150000  21.683333  21.036667  21.400000   62784975      0.0          1.0
# 2  20.974667  21.236667  20.378667  20.858000  148738980      0.0          1.0
# 3  21.105333  21.149333  20.800000  21.108000   68680935      0.0          1.0
# 4  22.427333  22.468000  21.033333  21.066667  146655885      0.0          1.0

# %%
df1.tail()
# Out:
#      symbol                       date   close    high     low    open  \
# 1402   TSLA  2023-07-31 00:00:00+00:00  267.43  269.08  263.78  267.48
# 1403   TSLA  2023-08-01 00:00:00+00:00  261.07  266.47  260.25  266.26
# 1404   TSLA  2023-08-02 00:00:00+00:00  254.11  259.52  250.49  255.57
# 1405   TSLA  2023-08-03 00:00:00+00:00  259.32  260.49  252.00  252.04
# 1406   TSLA  2023-08-04 00:00:00+00:00  253.86  264.77  253.11  260.97
#
#          volume  adjClose  adjHigh  adjLow  adjOpen  adjVolume  divCash  \
# 1402   84582172    267.43   269.08  263.78   267.48   84582172      0.0
# 1403   83645720    261.07   266.47  260.25   266.26   83645720      0.0
# 1404  101752865    254.11   259.52  250.49   255.57  101752865      0.0
# 1405   97829545    259.32   260.49  252.00   252.04   97829545      0.0
# 1406   99539907    253.86   264.77  253.11   260.97   99539907      0.0
#
#       splitFactor
# 1402          1.0
# 1403          1.0
# 1404          1.0
# 1405          1.0
# 1406          1.0

# %% [markdown]
# **Selecting Open value**

# %%
df=df1['open']

# %%
df.shape
# Out:
# (1407,)

# %%
df.head()
# Out:
# 0    312.00
# 1    321.00
# 2    312.87
# 3    316.62
# 4    316.00
# Name: open, dtype: float64

# %% [markdown]
# **Data Visualization**

# %%
plt.plot(df)

# %%
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
df
# Out:
# array([[0.0953415 ],
#        [0.09944711],
#        [0.09573837],
#        ...,
#        [0.06959929],
#        [0.06798898],
#        [0.07206266]])

# %%
plt.plot(df)

# %%
training_size=int(len(df)*0.65)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
training_size,test_size
# Out:
# (914, 493)

# %% [markdown]
# **Data Preprocessing for Time Serise Data**

# %%
def Preprocess_data(dataset,time_step):
  X,Y=[],[]
  for i in range(len(dataset)-time_step-1):
    a=dataset[i:(i+time_step),0]
    X.append(a)
    b=dataset[i+time_step,0]
    Y.append(b)

  return numpy.array(X),numpy.array(Y)

# %%
x_train,y_train = Preprocess_data(train_data,365)
x_test,y_test = Preprocess_data(test_data,365)

# %% [markdown]
# x_train.shape

# %%
x_train=x_train.reshape(x_train.shape[0],x_train.shape[1],1)
x_test=x_test.reshape(x_test.shape[0],x_test.shape[1],1)
x_test.shape
# Out:
# (127, 365, 1)

# %% [markdown]
# **Model Engineering**

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(365,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 365, 50)           10400
#
#  lstm_4 (LSTM)               (None, 365, 50)           20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Model Training**

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 8s 507ms/step - loss: 0.0234 - accuracy: 0.0000e+00 - val_loss: 0.0055 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 9/9 [==============================] - 4s 427ms/step - loss: 0.0134 - accuracy: 0.0000e+00 - val_loss: 0.0041 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 9/9 [==============================] - 4s 429ms/step - loss: 0.0108 - accuracy: 0.0018 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 9/9 [==============================] - 4s 429ms/step - loss: 0.0101 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 9/9 [==============================] - 4s 441ms/step - loss: 0.0083 - accuracy: 0.0018 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 9/9 [==============================] - 4s 450ms/step - loss: 0.0076 - accuracy: 0.0018 - val_loss: 2.7472e-04 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 9/9 [==============================] - 4s 445ms/step - loss: 0.0076 - accuracy: 0.0018 - val_loss: 8.3524e-04 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 9/9 [==============================] - 4s 461ms/step - loss: 0.0072 - accuracy: 0.0018 - val_loss: 3.9924e-04 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 9/9 [==============================] - 4s 440ms/step - loss: 0.0067 - accuracy: 0.0018 - val_loss: 2.7519e-04 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 9/9 [==============================] - 4s 432ms/step - loss: 0.0066 - accuracy: 0.0018 - val_loss: 6.4654e-04 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 9/9 [==============================] - 4s 431ms/step - loss: 0.0063 - accuracy: 0.0018 - val_loss: 7.0656e-05 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 9/9 [==============================] - 4s 436ms/step - loss: 0.0061 - accuracy: 0.0018 - val_loss: 5.8179e-04 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 9/9 [==============================] - 4s 428ms/step - loss: 0.0059 - accuracy: 0.0018 - val_loss: 2.4307e-04 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 9/9 [==============================] - 4s 445ms/step - loss: 0.0055 - accuracy: 0.0018 - val_loss: 7.1004e-05 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 9/9 [==============================] - 4s 431ms/step - loss: 0.0052 - accuracy: 0.0018 - val_loss: 7.9604e-05 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 9/9 [==============================] - 7s 802ms/step - loss: 0.0049 - accuracy: 0.0018 - val_loss: 9.0328e-05 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.0049 - accuracy: 0.0018 - val_loss: 1.3784e-04 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 9/9 [==============================] - 6s 567ms/step - loss: 0.0054 - accuracy: 0.0018 - val_loss: 3.1415e-04 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 9/9 [==============================] - 4s 448ms/step - loss: 0.0045 - accuracy: 0.0018 - val_loss: 3.4290e-04 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 9/9 [==============================] - 4s 443ms/step - loss: 0.0042 - accuracy: 0.0018 - val_loss: 5.4135e-04 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 9/9 [==============================] - 4s 448ms/step - loss: 0.0037 - accuracy: 0.0018 - val_loss: 1.1294e-04 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 9/9 [==============================] - 4s 485ms/step - loss: 0.0035 - accuracy: 0.0018 - val_loss: 5.7685e-04 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 9/9 [==============================] - 4s 472ms/step - loss: 0.0034 - accuracy: 0.0018 - val_loss: 1.0042e-04 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 9/9 [==============================] - 4s 443ms/step - loss: 0.0037 - accuracy: 0.0018 - val_loss: 3.2698e-04 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 9/9 [==============================] - 4s 451ms/step - loss: 0.0029 - accuracy: 0.0018 - val_loss: 2.2156e-04 - val_accuracy: 0.0000e+00
# Epoch 26/100
#
- val_accuracy: 0.0000e+00
# Epoch 81/100
# 9/9 [==============================] - 4s 491ms/step - loss: 0.0015 - accuracy: 0.0018 - val_loss: 5.3970e-05 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 9/9 [==============================] - 4s 493ms/step - loss: 0.0014 - accuracy: 0.0018 - val_loss: 9.0878e-05 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 9/9 [==============================] - 4s 499ms/step - loss: 0.0015 - accuracy: 0.0018 - val_loss: 6.1385e-05 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 9/9 [==============================] - 4s 492ms/step - loss: 0.0013 - accuracy: 0.0018 - val_loss: 4.9145e-05 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 9/9 [==============================] - 4s 482ms/step - loss: 0.0017 - accuracy: 0.0018 - val_loss: 2.6244e-04 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 9/9 [==============================] - 4s 489ms/step - loss: 0.0014 - accuracy: 0.0018 - val_loss: 4.6546e-05 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 9/9 [==============================] - 4s 488ms/step - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 9.6888e-05 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 9/9 [==============================] - 4s 481ms/step - loss: 0.0019 - accuracy: 0.0018 - val_loss: 1.2620e-04 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 9/9 [==============================] - 4s 490ms/step - loss: 0.0015 - accuracy: 0.0018 - val_loss: 3.6858e-05 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 9/9 [==============================] - 4s 485ms/step - loss: 0.0015 - accuracy: 0.0018 - val_loss: 3.7011e-05 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 9/9 [==============================] - 5s 520ms/step - loss: 0.0014 - accuracy: 0.0018 - val_loss: 9.5584e-05 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 9/9 [==============================] - 4s 495ms/step - loss: 0.0015 - accuracy: 0.0018 - val_loss: 3.5440e-05 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 9/9 [==============================] - 4s 462ms/step - loss: 0.0013 - accuracy: 0.0018 - val_loss: 1.4015e-04 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 9/9 [==============================] - 4s 488ms/step - loss: 0.0017 - accuracy: 0.0018 - val_loss: 1.8374e-04 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 9/9 [==============================] - 4s 473ms/step - loss: 0.0013 - accuracy: 0.0018 - val_loss: 1.2792e-04 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 9/9 [==============================] - 4s 465ms/step - loss: 0.0013 - accuracy: 0.0018 - val_loss: 6.1509e-05 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 9/9 [==============================] - 4s 466ms/step - loss: 0.0013 - accuracy: 0.0018 - val_loss: 1.2536e-04 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 9/9 [==============================] - 4s 470ms/step - loss: 0.0014 - accuracy: 0.0018 - val_loss: 5.1619e-05 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 9/9 [==============================] - 4s 461ms/step - loss: 0.0015 - accuracy: 0.0018 - val_loss: 2.1622e-04 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 9/9 [==============================] - 4s 469ms/step - loss: 0.0014 - accuracy: 0.0018 - val_loss: 6.0066e-05 - val_accuracy: 0.0000e+00

# %% [markdown]
# **MODEL PREDICTION**

# %%
train_pred=model.predict(x_train)
test_pred=model.predict(x_test)
# Out:
# 18/18 [==============================] - 2s 84ms/step
# 4/4 [==============================] - 0s 87ms/step

# %%
train_pred.shape
# Out:
# (548, 1)

# %% [markdown]
# **Train Prediction**

# %%
plt.plot(y_train,label='Actual_train_target value')
plt.plot(train_pred)

# %%
y_train.shape
# Out:
# (548,)

# %%
test_pred.shape
# Out:
# (127, 1)

# %% [markdown]
# **Test Prediction**

# %%
plt.plot(y_test,label='test actual data')
plt.plot(test_pred,label='test predicted data')

# %% [markdown]
# **Calculating RMSE**

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 726.7297476166528

# %%
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 224.6548067192766

# %% [markdown]
# **Ploting test and train predicted dat on original data**

# %%
import numpy as np
import matplotlib.pyplot as plt


look_back = 365

trainPredictPlot = np.full_like(df, np.nan)
testPredictPlot = np.full_like(df, np.nan)

train_predict_reshaped = train_predict.reshape(-1, 1)
test_predict_reshaped = test_predict.reshape(-1, 1)

trainPredictPlot[look_back:look_back+len(train_predict_reshaped)] = train_predict_reshaped


testPredictPlot[look_back*2+len(train_predict_reshaped):look_back*2+len(train_predict_reshaped)+len(test_predict_reshaped)] = test_predict_reshaped

plt.plot(df1['open'])
plt.plot(trainPredictPlot, color='red')
plt.plot(testPredictPlot, color='orange')
plt.show()

# %% [markdown]
# **Predicting Future 90 days Stocks**

# %%
n_days = 90
x_input = test_data[-90:].reshape(1, -1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()
lst_output = []
n_steps = 365

for i in range(n_days):
    if len(temp_input) >= n_steps:
        x_input = np.array(temp_input[-n_steps:])  # Use the last n_steps elements
        x_input = x_input.reshape(1, n_steps, 1)
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
    else:
        x_input = np.array(temp_input)
        x_input = x_input.reshape(1, len(temp_input), 1)  # Use all available data
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())


extended_predictions = scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

day_new_extended = np.arange(len(df1), len(df1) + n_days)

# %%
print(lst_output)
# Out:
# [[0.07649081200361252], [0.07624440640211105], [0.07650671899318695], [0.07714015245437622], [0.07800483703613281], [0.07899931818246841], [0.0800628587603569], [0.0811644196510315], [0.08229045569896698], [0.08343586325645447], [0.08459854125976562], [0.08577679842710495], [0.08696837723255157], [0.08817046135663986], [0.08937983214855194], [0.0905931293964386], [0.09180723130702972], [0.09301916509866714], [0.0942264199256897], [0.09542682766914368], [0.09661854803562164], [0.09780015051364899], [0.09897053241729736], [0.10012891888618469], [0.10127469152212143], [0.10240766406059265], [0.10352768003940582], [0.10463477671146393], [0.10572923719882965], [0.10681135952472687], [0.10788155347108841], [0.10894031077623367], [0.10998817533254623], [0.11102568358182907], [0.11205343902111053], [0.11307202279567719], [0.11408206075429916], [0.11508405208587646], [0.11607860773801804], [0.11706622689962387], [0.11804745346307755], [0.11902274936437607], [0.11999257653951645], [0.1209573894739151], [0.12191751599311829], [0.12287339568138123], [0.12382533401250839], [0.12477363646030426], [0.1257186233997345], [0.1266605108976364], [0.1275995969772339], [0.12853609025478363], [0.12947018444538116], [0.1304020881652832], [0.13133203983306885], [0.13226011395454407], [0.13318651914596558], [0.1341114640235901], [0.1350349485874176], [0.1359572857618332], [0.13687849044799805], [0.13779878616333008], [0.13871821761131287], [0.1396370232105255], [0.14055520296096802], [0.14147299528121948], [0.14239048957824707], [0.14330780506134033], [0.14422515034675598], [0.1451425850391388], [0.1460602581501007], [0.14697831869125366], [0.1478969156742096], [0.14881619811058044], [0.14973628520965576], [0.15065732598304749], [0.15157952904701233], [0.15250298380851746], [0.1534278392791748], [0.15435436367988586], [0.15528258681297302], [0.156212717294693], [0.1571449339389801], [0.15807941555976868], [0.15901628136634827], [0.15995576977729797], [0.16089800000190735], [0.1618432104587555], [0.16279157996177673], [0.16374316811561584]]

# %%
plt.plot(extended_predictions)

# %% [markdown]
# **Ploting future 90days data on original data**

# %%
plt.plot(df1['open'])
plt.savefig('predicted_plot.jpg')
plt.plot(day_new_extended,extended_predictions, label="Test Prediction", color="green")
plt.savefig('plot.jpg')

# %% [markdown]
# **Saving the model**

# %%
model.save('Amazon_Lstm_stock_model.h5')
# Out:
# C:\Users\abinj\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
